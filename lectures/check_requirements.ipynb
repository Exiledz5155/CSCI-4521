# %% [markdown]
# ---
# <h1 style="text-align: center;">
# Welcome to CSCI 4521: Applied Machine Learning
# <br><br>
# Lecture 1: Introduction
# </h1>
#
# ---

# %% [markdown]
# <h3 style="text-align: center;">
# Instructor: Nicholas Johnson
# <br><br>
# September 3, 2024
# </h3>

# %% [markdown]
# ---

# %% [markdown]
# ## General Information
#
# ### Lectures: Tue, Thu 5:45 - 7 PM CT
# ### Location: Mechanical Engineering 108

# %% [markdown]
# ## TAs:
# - ### Risako Owan
# - ### Bang Ly
# - ### Yashas Acharya

# %% [markdown]
# ## Office Hours:
# - ### Nick:
#     - #### Tue: 7-8 PM (maybe here, otherwise in Keller Hall 6-196)
#     - #### Wed: 4:00-5:00 PM (via Zoom)
# - ### Risako:
#     - #### Mon/Thu: 10 - 11 AM (Shepherd 161)
# - ### Bang:
#     - #### Fri: 10 AM-12 PM (Lind L103)
# - ### Yasha:
#     -  #### Tue: 9 - 10 AM (Keller Hall 1-201)

# %% [markdown]
# ## Email:
# - ### Nick: njohnson@cs.umn.edu
# - ### Risako: owan0002@umn.edu
# - ### Bang: ly000051@umn.edu
# - ### Yashas achar100@umn.edu

# %% [markdown]
# ---

# %% [markdown]
# ## Books
#
# [![islp.png](attachment:f4520a6d-72d8-4778-bf08-5c1e5294d63f.png)](https://hastie.su.domains/ISLP/ISLP_website.pdf.download.html)
# [![adsp.png](attachment:cadceda1-aa48-45e6-a302-0cedd21ecef4.png)](https://primo.lib.umn.edu/discovery/fulldisplay?docid=alma9977532267801701&context=L&vid=01UMN_INST:TWINCITIES&lang=en&search_scope=TwinCitiesCampus_and_CI&adaptor=Local%20Search%20Engine&tab=Everything&query=any,contains,pyspark&facet=rtype,include,books&offset=0)
# [![pda.png](attachment:9f247984-091d-4168-94fe-8b4d1aa87e0c.png)](https://wesmckinney.com/book/)

# %% [markdown]
# ---

# %% [markdown]
# ## Course Work
# ### Class Participation (10%)
# - All-or-nothing credit per week
# - You must post one reasonable question and answer one question on the class discussion forum each week of the semester
# - Each week ends on Sunday at 11:59 PM CT
# - Each week counts for 2/3% of your final grade
#
# ### 6 Homeworks (90%)
# - Each worth 15% of final grade
# - Each due at 11:59 PM CT on due date (submit via Canvas)
# - Each must be done individually (high-level discussions are OK)
# - All coding must be done with Python 3.12+ (no other languages will be accepted)
# - Focus on:
#     - **Writing high-quality code**
#     - **Using software engineering, data science, and machine learning tools**
#     - **Experimentation, failing, effort, and learning**
#
# #### Must complete all homeworks with score > 0 on each and overall class participation score > 0 to pass the class

# %% [markdown]
# ## Homeworks: Late Submission Policy
#
# ### You have a total of 6 grace days (for the entire semester)
# ### You can choose to use them as convenient to delay one+ homeworks
# ### Delay gets rounded up to a day
# - Late by 45 mins = late by a (grace) day
# - Late by 23 hrs 45 mins = late by a (grace) day
# ### Delays beyond the grace days:
# - Late by 0-24 hrs: 50% of actual score
# - Late by 24-48 hrs: 25% of actual score
# - Late by > 48 hrs: Will receive a zero

# %% [markdown]
# ---

# %% [markdown]
# ## Grading
#
# ### Class participation: 10%
# ### Homeworks: 90%
# - #### 10% of each homework grade will be only on code quality (more details below)
#
# ### Grading is absolute (i.e., not on a curve)
# ### For S/N grading, a satisfactory grade (S) requires at least a C-
#
# ### See syllabus for grade lines

# %% [markdown]
# ---

# %% [markdown]
# ## Topics
# - #### Python, jupyter notebooks, code quality
# - #### Pandas, loading and analyzing data, missing/imbalanced data
# - #### Exploratory data analysis (EDA)
# - #### Visualizing data, matplotlib/seaborn
# - #### PySpark
# - #### Preprocessing data, cross validation, data leakage, numpy
# - #### Scikit-learn
# - #### Classification Algorithms
# - #### Classification loss functions and metrics
# - #### Overfitting/regularization, model evaluation, hyperparameter tuning, Tensorboard
# - #### Regression Algorihms
# - #### Working with images and text data
# - #### Neural networks and deep learning
# - #### PyTorch
# - #### Unsupervised learning algorithms

# %% [markdown]
# ## What we will not cover
# - #### In-depth math/theory
# - #### Many Big Data tools
# - #### Model deployment
# - #### (Vector) Databases
# - #### Large language models/ChatGPT
# - #### Generative AI
# - #### Many other topics in ML

# %% [markdown]
# ---

# %% [markdown]
# # What is Machine Learning?
#
# > ### "Machine learning is programming computers to optimize a performance criterion using example data or past experience" - Ethem Alpaydin
#
# <br><br>

# %% [markdown]
# ![machine-learning1.png](attachment:c5eda1ff-a19d-4608-aae1-57a5491d6791.png)
#
# ###### https://www.wordstream.com/blog/ws/2017/07/28/machine-learning-applications

# %% [markdown]
# ## Supervised Learning
#
# - ### Learn mapping from input to ouput
# - ### Utilizes labeled dataset
#     - Input-ouput (features, labels or target values) pairs
#     - Supervisor tells algorithm correct answer
# - ### Classification, regression, anomaly detection, etc.
# - ### Example applications:
#     - Movie predictions
#     - Stock price prediction
#     - Face recognition

# %% [markdown]
# ## Unsupervised Learning
#
# - ### Learn "what normally happens"
# - ### No output (labels)
# - ### Clustering: grouping similar instances
# - ### Example applications:
#     - Customer segmentation
#     - Image compression: color quantization
#     - Bioinformatics: learning motifs

# %% [markdown]
# ## Reinforcement Learning
#
# - ### Learn via interacting with environment (i.e., trial and error)
# - ### Consists of observing environment state, taking action, receiving reward
# - ### No supervisor to tell you correct answer
# - ### Only relative rewards give clue of action quality
# - ### Example applications:
#     - Recommender systems / personalization
#     - Manufacturing optimization
#     - Game playing (e.g., Mario)
#     - Robot search and rescue
#     - Path planning
#     - Drug discovery

# %% [markdown]
# ---

# %% [markdown]
# ## Machine Learning Pipeline
#
# ![ml_pipeline.png](attachment:1936a080-09ed-4562-b55f-df88cda346d8.png)
#
# ###### https://medium.com/microsoftazure/how-to-accelerate-devops-with-machine-learning-lifecycle-management-2ca4c86387a0

# %% [markdown]
# ---

# %% [markdown]
# ## ML Examples
#
# ### [This Person Does Not Exist](https://thispersondoesnotexist.com/)
#
# ### [DALL-E](https://openai.com/dall-e-2/)
#
# ### [Mario Kart](https://www.youtube.com/watch?v=Tnu4O_xEmVk)

# %% [markdown]
# ---

# %% [markdown]
# ## Code Quality
#
# ### I expect you to write high-quality code
#
# ### Read
#
# [Clean Code book](https://www.amazon.com/Clean-Code-Handbook-Software-Craftsmanship/dp/0132350882) (Ch. 1-5 at a minimum, 1-7 is best)
#
# ![clean_code.png](attachment:5c9aacd5-ab7b-4327-8457-63635e6cd4a1.png)
#
# ## Your code must have:
# - #### Well-named variables (do not use single character variables!), functions, and classes
# - #### Write many, **small** functions/classes (> 50 lines of code is too long, > 3 variables is too many)
# - #### Functions should do only **one** thing (single-responsibility principle)
# - #### Don't repeat yourself (DRY principle)
# - #### Use comments sparingly (bad comments are worse than no comments)
# - #### Use whitespace both vertically and horizontally (newpaper metaphor)
# - #### Use objects (as necessary) and the correct data structures (i.e., do not use a list when a set will do)
# - #### Error handling and (unit) testing is great but likely not needed for this class
# - #### Be careful using notebooks; great for rapid experimentation/analysis/exposition but bad for code reuse and prone to bugs
# - #### Use [type hints](https://docs.python.org/3/library/typing.html)
# - #### Strongly encourage using a linter like [flake8](https://flake8.pycqa.org/en/latest/)
# - #### Strongly encourage using a type checker like [mypy](https://mypy-lang.org/)
# - #### Strongly encourage using [Git/Github](https://github.com)
#
# ## 10% of each homework grade will be on code quality

# %% [markdown]
# ### Example of how choosing the correct data structure affects code speed

# %%
import numpy as np
import time

def find_char(data: list | set, char: str) -> bool:
    start = time.time()
    char_present = char in data
    end = time.time()
    print(f"Time (in s) to find char: {end - start}")
    
    return char in data

num_data = 1000000

char = "a"
rand_data = np.random.rand(num_data)

# find char in list
data = list(rand_data) + [char]
print(f"List len: {len(data)}")
print(find_char(data, char))

# find char in set
data = set(rand_data)
data.add(char)
print(f"Set len: {len(data)}")
print(find_char(data, char))
# Out:
# List len: 1000001
# Time (in s) to find char: 3.165990114212036
# True
# Set len: 1000001
# Time (in s) to find char: 0.0
# True

# %% [markdown]
# ### `in` operator has average time complexity $O(n)$ when using a list and $O(1)$ when using a set

# %% [markdown]
# ---

# %% [markdown]
# ### What does the following code do?

# %%
# this is bad code
import numpy as np
a=[[1,2,3],[4,5,6]]
a =np.array(a) # create an list
a=np.max(a,axis=0)
maxa = max(a)
b=[[10,11,12],[13,14,15]]
b=np.array(b)
b=    np.max(b,axis=0)
maxb=max(b) # find the max of b
a=maxa-maxb
# add 3 to each element in array
a= 5+a
print(a)
a=[[1,1,2],[3,5,8]]
a=np.array(a)
a= np.max(a,  axis =0)
maxa = max(a)
b=[[11,11,22],[33,55,88]]
b=np.array(b)
b     =np.max(b,axis=0)
maxb=max(b)
a=maxa-maxb
# add 3 to each element in array
a= 3+a
print(a)
# Out:
# -4
# -77

# %% [markdown]
# ### How do we improve this code?

# %%
# this is better code
import numpy as np

def subtract_two_largest_and_add(first_array: np.ndarray, second_array: np.ndarray, scalar_to_add: float = 0) -> float:
    return np.max(first_array) - np.max(second_array) + scalar_to_add

first_array = np.array([[1,2,3],[4,5,6]])
second_array = np.array([[10,11,12],[13,14,15]])

print(subtract_two_largest_and_add(first_array, second_array, scalar_to_add = 5))


first_array = np.array([[1,1,2],[3,5,8]])
second_array = np.array([[11,11,22],[33,55,88]])

print(subtract_two_largest_and_add(first_array, second_array, scalar_to_add = 3))
# Out:
# -4
# -77

# %% [markdown]
# ---

# %% [markdown]
# ### Lectures will likely be 45-60 minutes. Remaining 15-30 minutes will be devoted to solving practice problems.

# %% [markdown]
# # Practice Problems

# %% [markdown]
# ### 1. Install the following **in a virtual environment**:
# - #### Python 3.12.4
# - #### Jupyter Notebook (use latest version)
# - #### Pandas 2.2.2
# - #### Numpy 1.26.4
# - #### Matplotlib 3.8.4
# - #### Seaborn 0.13.2
# - #### Scikit-learn 1.4.2
# - #### PyTorch 2.3.0
# - #### Tensorboard 2.17.0
#
# #### You can do this however you want but it's probably easiest via [Anaconda](https://www.anaconda.com/download/success).
# #### Download and install Anaconda (it may take a while), it should include all the above packages except Torch and Tensorboard.
# #### Once you've installed Anaconda, open an Anaconda terminal and create a virtual environment with the command:
# ```
# conda create -n csci4521 python=3.12.4 anaconda
# ```
# #### This will create a virtual environment with the correct Python version and Anaconda packages. If you're not using Anaconda, feel free to create a virtual environment in another way (e.g., pyenv, venv, Poetry, etc.)

# %% [markdown]
# ### 2. If you installed Anaconda, open the Anaconda terminal and start a Jupyter notebook with the command: `jupyter notebook`. This will open a web browser where you can create a new notebook or open an existing notebook.

# %% [markdown]
# ## 3. In your Anaconda terminal, install PyTorch and Tensorboard with the command:
# ```
# conda install pytorch torchvision tensorboard
# ```
# #### (You can also install via pip.)
#
# Now, in your notebook, run the following:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import sklearn
import torch
import tensorboard

# %% [markdown]
# ### The above cell should run without error
